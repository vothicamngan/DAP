# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("FoodPrice_in_Turkey.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Place        7381 non-null   object
#  1   ProductId    7381 non-null   int64
#  2   ProductName  7381 non-null   object
#  3   UmId         7381 non-null   int64
#  4   UmName       7381 non-null   object
#  5   Month        7381 non-null   int64
#  6   Year         7381 non-null   int64
#  7   Price        7381 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 461.4+ KB

# %%
data.describe()
# Out:
#          ProductId         UmId        Month         Year        Price
# count  7381.000000  7381.000000  7381.000000  7381.000000  7381.000000
# mean    254.509687    15.252811     6.479881  2017.458474    15.738709
# std     141.008599    25.276665     3.530361     1.499256    22.418284
# min      52.000000     5.000000     1.000000  2013.000000     0.253900
# 25%     114.000000     5.000000     3.000000  2017.000000     3.223600
# 50%     239.000000     5.000000     6.000000  2018.000000     5.909600
# 75%     388.000000     5.000000    10.000000  2019.000000    20.441900
# max     502.000000   102.000000    12.000000  2019.000000   159.445800

# %%
data.dropna()
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# ...

# %%
data.describe()
# Out:
#          ProductId         UmId        Month         Year        Price
# count  7381.000000  7381.000000  7381.000000  7381.000000  7381.000000
# mean    254.509687    15.252811     6.479881  2017.458474    15.738709
# std     141.008599    25.276665     3.530361     1.499256    22.418284
# min      52.000000     5.000000     1.000000  2013.000000     0.253900
# 25%     114.000000     5.000000     3.000000  2017.000000     3.223600
# 50%     239.000000     5.000000     6.000000  2018.000000     5.909600
# 75%     388.000000     5.000000    10.000000  2019.000000    20.441900
# max     502.000000   102.000000    12.000000  2019.000000   159.445800

# %%
y1 = data[(data['Year']==2019)&(data['Month']==12)&(data['ProductName']=="Milk (powder, infant formula) - Retail")].reset_index()
y1
# Out:
#    index             Place  ProductId                             ProductName  \
# 0   2382  National Average        442  Milk (powder, infant formula) - Retail
# 1   3998            Ankara        442  Milk (powder, infant formula) - Retail
# 2   5581          Istanbul        442  Milk (powder, infant formula) - Retail
# 3   7164             Izmir        442  Milk (powder, infant formula) - Retail
#
#    UmId UmName  Month  Year     Price
# 0     5     KG     12  2019  124.8845
# 1     5     KG     12  2019  128.4533
# 2     5     KG     12  2019  122.7862
# 3     5     KG     12  2019  147.1558

# %%
y2 = data[(data['Year']==2019)&(data['Month']==12)&(data['ProductName']=="Fuel (gas) - Retail")].reset_index()
y2
# Out:
#    index             Place  ProductId          ProductName  UmId UmName  \
# 0   1928  National Average        341  Fuel (gas) - Retail    90  12 KG
# 1   3667            Ankara        341  Fuel (gas) - Retail    90  12 KG
# 2   5250          Istanbul        341  Fuel (gas) - Retail    90  12 KG
# 3   6833             Izmir        341  Fuel (gas) - Retail    90  12 KG
#
#    Month  Year     Price
# 0     12  2019  108.5535
# 1     12  2019  106.0534
# 2     12  2019  112.4568
# 3     12  2019  109.1172

# %%
data1 = pd.DataFrame({'x': y1['Place'], 'y1': y1['Price'], 'y2':y2['Price']})

# %%
data1
# Out:
#                   x        y1        y2
# 0  National Average  124.8845  108.5535
# 1            Ankara  128.4533  106.0534
# 2          Istanbul  122.7862  112.4568
# 3             Izmir  147.1558  109.1172

# %%
data1.plot(x='x',y=['y1','y2'], kind='bar')
# Out:
# <Axes: xlabel='x'>

# %%
data_rice_2016 =data[(data['Year']==2016)&(data['Place']=='National Average')&(data['ProductName']=='Rice - Retail')]
data_rice_2017 =data[(data['Year']==2017)&(data['Place']=='National Average')&(data['ProductName']=='Rice - Retail')]
data_rice_2018 =data[(data['Year']==2018)&(data['Place']=='National Average')&(data['ProductName']=='Rice - Retail')]
data_rice_2019 =data[(data['Year']==2018)&(data['Place']=='National Average')&(data['ProductName']=='Rice - Retail')]
data_gas_2016 =data[(data['Year']==2016)&(data['Place']=='National Average')&(data['ProductName']=='Fuel (gas) - Retail')]
data_gas_2017 =data[(data['Year']==2017)&(data['Place']=='National Average')&(data['ProductName']=='Fuel (gas) - Retail')]
data_gas_2018 =data[(data['Year']==2018)&(data['Place']=='National Average')&(data['ProductName']=='Fuel (gas) - Retail')]
data_gas_2019 =data[(data['Year']==2018)&(data['Place']=='National Average')&(data['ProductName']=='Fuel (gas) - Retail')]

# %%
data_rice_2016
# Out:
#                Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 27  National Average         52  Rice - Retail     5     KG      1  2016
# 28  National Average         52  Rice - Retail     5     KG      2  2016
# 29  National Average         52  Rice - Retail     5     KG      3  2016
# 30  National Average         52  Rice - Retail     5     KG      4  2016
# 31  National Average         52  Rice - Retail     5     KG      5  2016
# 32  National Average         52  Rice - Retail     5     KG      6  2016
# 33  National Average         52  Rice - Retail     5     KG      7  2016
# 34  National Average         52  Rice - Retail     5     KG      8  2016
# 35  National Average         52  Rice - Retail     5     KG      9  2016
# 36  National Average         52  Rice - Retail     5     KG     10  2016
# 37  National Average         52  Rice - Retail     5     KG     11  2016
# 38  National Average         52  Rice - Retail     5     KG     12  2016
#
#     Price
# ...

# %%
fig, ax = plt.subplots(3, 2)
ax[0][0].plot(data_rice_2016['Month'], data_rice_2016['Price'], marker = '*', label = 'Rice-2016')
ax[0][0].plot(data_gas_2016['Month'], data_gas_2016['Price'], marker = 's', label = 'Gas-2016')
ax[0][0].set_ylabel('Price')
ax[0][0].set_xticklabels([])
ax[0][0].set_title('2016')

ax[1][0].plot(data_rice_2017['Month'], data_rice_2017['Price'], marker = '*', label = 'Rice-2017')
ax[1][0].plot(data_gas_2017['Month'], data_gas_2017['Price'], marker = 's', label = 'Gas-2017')
ax[1][0].set_ylabel('Price')
ax[1][0].set_xticklabels([])
ax[1][0].set_title('2017')

ax[2][0].plot(data_rice_2018['Month'], data_rice_2018['Price'], marker = '*', label = 'Rice-2018')
ax[2][0].plot(data_gas_2018['Month'], data_gas_2018['Price'], marker = 's', label = 'Gas-2018')
ax[2][0].set_ylabel('Price')
ax[2][0].set_xticklabels([])
ax[2][0].set_title('2018')

ax[0][1].scatter(data_rice_2016['Month'], data_rice_2016['Price'])
ax[0][1].set_title('2016')
ax[0][1].set_ylabel('Rice')
ax[0][1].set_xticklabels([])
ax[0][1].set_title('2016')

ax[1][1].scatter(data_rice_2017['Month'], data_rice_2017['Price'])
ax[1][1].set_ylabel('Rice')
ax[1][1].set_xticklabels([])
ax[1][1].set_title('2017')

ax[2][1].scatter(data_rice_2018['Month'], data_rice_2018['Price'])
ax[2][1].set_ylabel('Rice')
ax[2][1].set_xticklabels([])
ax[2][1].set_title('2018')
# Out:
# Text(0.5, 1.0, '2018')
