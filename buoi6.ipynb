# %%
import pandas as pd
import numbers as np

df = pd.read_csv('shopeep_koreantop_clothing_shop_data.csv')
df_head = df.head()
df_head
# Out:
#              pk_shop date_collected     shopid                  name  \
# 0  20210613254711738     2021-06-13  254711738          hello.may.ph
# 1  20210613314198143     2021-06-13  314198143       love.women.shop
# 2   2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3   2021061321407329     2021-06-13   21407329           patriciacai
# 4   2021061311187885     2021-06-13   11187885  Little Market Manila
#
#   join_month  join_day  join_year  item_count  follower_count response_time  \
# 0      April        27       2020         446           17487      10:13:55
# 1  September        25       2020         263            8574      10:43:05
# 2  September        27       2016         209          660417      08:32:07
# 3      April        30       2017         165           18787      09:10:38
# 4    October        18       2016         467           67371      11:40:59
#
#    response_rate               shop_location  rating_bad  rating_good  \
# ...

# %%
df.columns
# Out:
# Index(['pk_shop', 'date_collected', 'shopid', 'name', 'join_month', 'join_day',
#        'join_year', 'item_count', 'follower_count', 'response_time',
#        'response_rate', 'shop_location', 'rating_bad', 'rating_good',
#        'rating_normal', 'rating_star', 'is_shopee_verified',
#        'is_official_shop'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 746 entries, 0 to 745
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   pk_shop             746 non-null    int64
#  1   date_collected      746 non-null    object
#  2   shopid              746 non-null    int64
#  3   name                746 non-null    object
#  4   join_month          746 non-null    object
#  5   join_day            746 non-null    int64
#  6   join_year           746 non-null    int64
#  7   item_count          746 non-null    int64
#  8   follower_count      746 non-null    int64
#  9   response_time       746 non-null    object
#  10  response_rate       746 non-null    int64
#  11  shop_location       428 non-null    object
#  12  rating_bad          746 non-null    int64
#  13  rating_good         746 non-null    int64
#  14  rating_normal       746 non-null    int64
#  15  rating_star         740 non-null    float64
# ...

# %%
df.describe()
# Out:
#             pk_shop        shopid    join_day    join_year   item_count  \
# count  7.460000e+02  7.460000e+02  746.000000   746.000000   746.000000
# mean   1.367361e+16  2.032431e+08   16.663539  2018.985255   482.886059
# std    8.764287e+15  1.425216e+08    8.897669     1.528625   604.620925
# min    2.021061e+14  1.083822e+06    1.000000  2015.000000     1.000000
# 25%    2.021063e+15  5.034141e+07    9.000000  2017.250000   145.500000
# 50%    2.021062e+16  2.054244e+08   17.000000  2019.000000   311.000000
# 75%    2.021063e+16  3.182721e+08   24.000000  2020.000000   526.000000
# max    2.021071e+16  4.689597e+08   31.000000  2021.000000  4739.000000
#
#        follower_count  response_rate     rating_bad   rating_good  \
# count    7.460000e+02     746.000000     746.000000  7.460000e+02
# mean     9.989943e+04      78.044236    2049.020107  9.720686e+04
# std      2.627164e+05      22.534672    9232.920595  3.417680e+05
# ...

# %%
df[['shop_location', 'shopid']]
# Out:
#                   shop_location     shopid
# 0                           NaN  254711738
# 1      San Nicolas,Metro Manila  314198143
# 2       Pasay City,Metro Manila   10377223
# 3          Binondo,Metro Manila   21407329
# 4    Caloocan City,Metro Manila   11187885
# ..                          ...        ...
# 741          Legazpi City,Albay  449182992
# 742                         NaN  396605392
# 743                         NaN  360379308
# 744        Binondo,Metro Manila   29392066
# 745     Pasay City,Metro Manila   25811092
#
# [746 rows x 2 columns]

# %%
df[['join_day', 'join_month','join_year']]
# Out:
#      join_day join_month  join_year
# 0          27      April       2020
# 1          25  September       2020
# 2          27  September       2016
# 3          30      April       2017
# 4          18    October       2016
# ..        ...        ...        ...
# 741        22        May       2021
# 742         3      March       2021
# 743        20   December       2020
# 744         2     August       2017
# 745        17       June       2017
#
# [746 rows x 3 columns]

# %%
df[0:8]
# Out:
#              pk_shop date_collected     shopid                      name  \
# 0  20210613254711738     2021-06-13  254711738              hello.may.ph
# 1  20210613314198143     2021-06-13  314198143           love.women.shop
# 2   2021061310377223     2021-06-13   10377223             R&O RedOrange
# 3   2021061321407329     2021-06-13   21407329               patriciacai
# 4   2021061311187885     2021-06-13   11187885      Little Market Manila
# 5  20210613430999411     2021-06-13  430999411             Bellamy House
# 6  20210613310915998     2021-06-13  310915998   Yihua Women's Wear Hall
# 7  20210613126018720     2021-06-13  126018720  croptop korean top dress
#
#   join_month  join_day  join_year  item_count  follower_count response_time  \
# 0      April        27       2020         446           17487      10:13:55
# 1  September        25       2020         263            8574      10:43:05
# 2  September        27       2016         209          660417      08:32:07
# ...

# %%
df[df['join_month']== 'April']
# Out:
#                pk_shop date_collected     shopid                     name  \
# 0    20210613254711738     2021-06-13  254711738             hello.may.ph
# 3     2021061321407329     2021-06-13   21407329              patriciacai
# 5    20210613430999411     2021-06-13  430999411            Bellamy House
# 13    2021061364909141     2021-06-13   64909141  ikon Bra Dress Crop top
# 17    2021061320477406     2021-06-13   20477406         PinSan UnderWear
# ..                 ...            ...        ...                      ...
# 724  20210706419928844     2021-07-06  419928844       Only For You，today
# 735  20210706141606030     2021-07-06  141606030        🌿 Peppermint Shop
# 737  20210706416886409     2021-07-06  416886409                 vaapo.ph
# 738  20210706419954100     2021-07-06  419954100    Fall in love with you
# 739   2021070664360491     2021-07-06   64360491                Yzkzks.ph
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# ...

# %%
df[(df['join_year']==2021)&(df['follower_count']>=10000)]
# Out:
#                pk_shop date_collected     shopid                   name  \
# 23   20210613418672464     2021-06-13  418672464                 xuxixi
# 326  20210621419954100     2021-06-21  419954100  Fall in love with you
# 365  20210628418672464     2021-06-28  418672464                 xuxixi
# 389  20210628373953071     2021-06-28  373953071             LK Shop ph
# 558  20210706382931801     2021-07-06  382931801  Stop And Shop Fashion
# 561  20210706373953071     2021-07-06  373953071             LK Shop ph
# 572  20210706418672464     2021-07-06  418672464     XuXi Apparel Store
# 738  20210706419954100     2021-07-06  419954100  Fall in love with you
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# 23       April         7       2021         220           10180      09:26:55
# 326      April         9       2021         662           12783      09:01:18
# 365      April         7       2021         220           13768      10:23:37
# ...

# %%
# lấy cột
df1 = df[['join_year', 'follower_count']]
# lọc hàng dựa trên điều kiện 
df2 = df1[(df1['join_year']==2021)&(df1['follower_count']>=10000)]
df2.head()
# Out:
#      join_year  follower_count
# 23        2021           10180
# 326       2021           12783
# 365       2021           13768
# 389       2021           25191
# 558       2021           39669

# %%
df.groupby('join_year')['rating_bad'].agg(['mean','max'])
# Out:
#                   mean     max
# join_year
# 2015       2315.000000    2387
# 2016       1226.111111    5002
# 2017       7515.858974  102833
# 2018       2567.390805   25325
# 2019        386.000000    5599
# 2020        188.530364    1523
# 2021         24.235294    1534

# %%
df.groupby('join_year')[['rating_bad','rating_good']].agg({'rating_bad':'mean','rating_good':'max'})
# Out:
#             rating_bad  rating_good
# join_year
# 2015       2315.000000       343050
# 2016       1226.111111      1153298
# 2017       7515.858974      3403406
# 2018       2567.390805      1256252
# 2019        386.000000       907602
# 2020        188.530364       152420
# 2021         24.235294        21058

# %%
df.groupby(['join_year','shop_location'])['rating_good'].agg('mean')
# Out:
# join_year  shop_location
# 2015       Taytay,Rizal                    334295.50
# 2016       Bacoor,Cavite                    25742.25
#            Caloocan City,Metro Manila       64265.60
#            Marikina City,Metro Manila        2550.00
#            Paranaque City,Metro Manila      33438.00
#                                              ...
# 2021       Santa Cruz,Metro Manila            345.00
#            Silang,Cavite                       48.00
#            Taytay,Rizal                     21058.00
#            Tondo I / Ii,Metro Manila         1717.00
#            Valenzuela City,Metro Manila     20346.50
# Name: rating_good, Length: 97, dtype: float64

# %%
df['District'] = df['shop_location'].str.split(',').str[0]
df['City'] = df['shop_location'].str.split(',').str[1]
df[['District', 'City']]
# Out:
#           District          City
# 0              NaN           NaN
# 1      San Nicolas  Metro Manila
# 2       Pasay City  Metro Manila
# 3          Binondo  Metro Manila
# 4    Caloocan City  Metro Manila
# ..             ...           ...
# 741   Legazpi City         Albay
# 742            NaN           NaN
# 743            NaN           NaN
# 744        Binondo  Metro Manila
# 745     Pasay City  Metro Manila
#
# [746 rows x 2 columns]

# %%
df = pd.DataFrame([[np.nan, 2, np.nan, 0],
                   [3, 4, np.nan, 1],
                   [np.nan, np.nan, np.nan, 5],
                   [np.nan, 3, np.nan, 4]],
                  columns=list("ABCD"))
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\TL DA LEARN\PhanTichDLPython\buoi6.ipynb Cell 15 line 2
#       <a href='vscode-notebook-cell:/e%3A/TL%20DA%20LEARN/PhanTichDLPython/buoi6.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
# ----> <a href='vscode-notebook-cell:/e%3A/TL%20DA%20LEARN/PhanTichDLPython/buoi6.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a>                    "toy": [np.nan, 'Batmobile', 'Bullwhip'],
#       <a href='vscode-notebook-cell:/e%3A/TL%20DA%20LEARN/PhanTichDLPython/buoi6.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a>                    "born": [pd.NaT, pd.Timestamp("1940-04-25"),
#       <a href='vscode-notebook-cell:/e%3A/TL%20DA%20LEARN/PhanTichDLPython/buoi6.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a>                             pd.NaT]})
#
# NameError: name 'np' is not defined
